# %% [markdown]
# # ERM with Real + Generated Data, Pruning, and Super-Label $u=(\varepsilon, y)$
#
# This notebook demonstrates how to **predict** and **empirically verify** the high-dimensional asymptotics of an ERM trained on a mixture of:
#
# - **real data** (weight $\varepsilon=1$),
# - **generated data** (weight $\varepsilon=\varepsilon(x,y)\in[0,1]$ given by a pruning/curation rule),
#
# using the *super-label* formalism:
# \[
# u = (\varepsilon, y),\qquad L_u(z) = \varepsilon\,\ell_y(z).
# \]

# %%
import sys, numpy as np
import matplotlib.pyplot as plt

# Make sure /mnt/data is on the import path
if "/mnt/data" not in sys.path:
    sys.path.insert(0, "/mnt/data")

# --- Core models / theory ---
from data_models import TeacherStudentModel,RealGeneratedPrunedModel, OracleMarginPruner, unit, make_aligned_vector,GaussianModel,MultiClassModel,UnifModel
from losses_regularizers import (
    SquaredLoss, LogisticLoss, HingeLoss,
    EpsScaledLoss,
    QuadraticRegularizer,
)
from erm_theory import ERMTrainer, TheoryFixedPointSolver

# %%
p = 30
mu0 = np.zeros(p)
mu1 = np.zeros(p)
mu0[:2] = 1.0
mu1[:2] = -1.0
C = np.eye(p)

g0 = GaussianModel(p=p, mu=mu0, C=C)
g1 = GaussianModel(p=p, mu=mu1, C=C)
r0 = UnifModel(p=p, mu=mu0, C=C)
r1 = UnifModel(p=p, mu=mu1, C=C)
x_model_g = MultiClassModel([g0, g1], gamma=[0.4, 0.6])
x_model_r = MultiClassModel([r0, r1], gamma=[0.4, 0.6])


n_train = 70          # total training samples
gamma_r = 0.05         # fraction real (gamma_g = 0.4)
rho = 0.7             # generator alignment with truth
rho_o = 0.9             # generator alignment with truth
lambda_gen = 2.0       # scales eps on generated samples

ridge = 2.0            # ridge strength in QuadraticRegularizer

# Teacher direction (truth)
rng = np.random.default_rng(seed=0)
w_star = unit(rng.standard_normal(size=p))
w_star = np.zeros(p)
w_star[0:5] = 1.0
# Generator direction with alignment rho
w_g = make_aligned_vector(w_star, rho=rho, rng=rng)
# Oracle direction (can be made imperfect if desired)
w_o = make_aligned_vector(w_star, rho=rho_o, rng=rng)

# Build real and generated data models (binary classification: y = sign(x^T w))
mu_x = np.zeros(p)
mu_x[0] = 3

real_model = TeacherStudentModel(
    x_model=x_model_r,
    theta_teacher=w_star,
    y_model="sign",
    noise_std=0.2,
)

gen_model = TeacherStudentModel(
    x_model=x_model_g,
    theta_teacher=w_g,
    y_model="sign",
    noise_std=0.2,
)

models = {'Real data': real_model, 'Generated data': gen_model}
# (x, y, epsi)

# L_{y,eps}(x) = eps l_y(x)

# Choose base loss (switchable)
base_loss = LogisticLoss()   # or SquaredLoss(), HingeLoss()
loss = EpsScaledLoss(base_loss=base_loss)

# Ridge regularizer
reg = QuadraticRegularizer(a=np.zeros(p), H=ridge * np.eye(p))

# %%
deltas_th
# Out:
# array([0., 2.])

# %%
deltas
# Out:
# array([0., 2.])

# %%
nb_points = 10
deltas = np.linspace(0, 2, nb_points)
ratio_th_emp = 5
nb_points_th = ratio_th_emp*(nb_points-1)+1
deltas_th = np.linspace(0, 2, nb_points_th)
rng = np.random.default_rng(1)
fp_damping =0.1
fp_tol = 5e-5
fp_max_iter = 1000
mc_samples = 10000
num_trials = 80
n_test = 10000

vars = {'Mixed data': {}}
for key in vars.keys():
    vars[key] = {
        'error_emp_means': [], 'error_emp_stds': [], 'error_classif_emp': [],
        'error_th': [], 'error_gaussian_score': [], 'error_classif_th': [],
        'nu': [],'mu': [], 'kappa': [], 'alpha': [],
    }
var_fixed_pt = ['mu', 'nu', 'kappa', 'alpha']
thetas_rcrd = dict()
for (idx,delta) in enumerate(deltas_th):
    # loss = ElasticL1L2Loss(lam)
    # Pruner: label-aware oracle-margin rule with threshold delta
    
    pruner = OracleMarginPruner(w_oracle=w_o, delta=delta, label_aware=True)

    # Combined model (returns u=(eps,y))
    models['Mixed data'] = RealGeneratedPrunedModel(
        real_model=models['Real data'],
        gen_model=models['Generated data'],
        pruner=pruner,
        gamma_r=gamma_r,
        lambda_gen=lambda_gen,
    )
    K = models['Mixed data'].class_params()['num_classes']
    if idx%ratio_th_emp ==0:
        
        print(f"\n===== delta = {delta:g} (empirical gen reg) =====")
        for model_name in ['Mixed data']:
            model = models[model_name]
            trainer = ERMTrainer(model=model, loss=loss, regularizer=reg)
            emp = trainer.run_trials(
                n_train=n_train,
                n_test=n_test,
                num_trials=num_trials,
                rng=rng,
                solver_maxiter=2000,
                tol=1e-6,
                method="L-BFGS-B",
                verbose=False,
            )
            # if idx==0 or idx ==nb_points-1:
            thetas_rcrd[(model_name, idx)] = trainer.thetas
            vars[model_name]['error_emp_means'].append(emp["gen_loss_mean"])
            vars[model_name]['error_emp_stds'].append(emp["gen_loss_std"])
            vars[model_name]['error_classif_emp'].append(model.error_classif_emp(thetas_rcrd[(model_name, idx)], n_test=n_test))
            
            print(f"Empirical loss for {model_name}: mean={emp['gen_loss_mean']:.6f}  std={emp['gen_loss_std']:.6f}   class. loss: {vars[model_name]['error_classif_emp'][-1]:.6f}")


    print(f"\n===== delta = {delta:g} (theory) =====")
    for model_name in ['Mixed data']:
        model = models[model_name]
        solver = TheoryFixedPointSolver(
            model=model,
            loss=loss,
            regularizer=reg,
            n_train=n_train,
            mc_samples=mc_samples,  # more samples for smaller etabda
            rng=np.random.default_rng(123),  # fixed for repeatability
        )

        th = solver.solve(
            max_iter=fp_max_iter,
            tol= fp_tol,
            damping= fp_damping,
            verbose=False,
            mu0=vars[model_name]['mu'][-1] if idx>0 else None,
            alpha0=[vars[model_name]['alpha'][-1][cl] for cl in range(K)] if idx>0 else None,
            nu0=[1/(1+vars[model_name]['kappa'][-1][cl]) for cl in range(K)] if idx>0 else None,
        )

        vars[model_name]['error_th'].append(th["predicted_loss"])
        vars[model_name]['error_classif_th'].append(model.error_classif_th(th["mu"], th["alpha"], num_trials=100000))

        # Warm start for next etabda
        for var in var_fixed_pt:
            vars[model_name][var].append(th[var])
        print(f"Theory predicted loss for {model_name} model: {th['predicted_loss']:.6f} class. loss: {vars[model_name]['error_classif_th'][-1]:.6f}  (converged={th['converged']}, iters={th['num_iter']}, damping_final={th.get('damping_final', float('nan')):.3f})")
        
# 5.20min
# Out:
# ===== delta = 0 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.778209  std=0.013580   class. loss: 0.227348
#
# ===== delta = 0 (theory) =====
# Theory predicted loss for Mixed data model: 0.776860 class. loss: 0.229630  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.0444444 (theory) =====
# Theory predicted loss for Mixed data model: 0.760006 class. loss: 0.229430  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.0888889 (theory) =====
# Theory predicted loss for Mixed data model: 0.742127 class. loss: 0.228060  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.133333 (theory) =====
# Theory predicted loss for Mixed data model: 0.724032 class. loss: 0.230910  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.177778 (theory) =====
# Theory predicted loss for Mixed data model: 0.704993 class. loss: 0.232770  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.222222 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.685253  std=0.018494   class. loss: 0.235449
#
# ===== delta = 0.222222 (theory) =====
# Theory predicted loss for Mixed data model: 0.685456 class. loss: 0.235180  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.266667 (theory) =====
# Theory predicted loss for Mixed data model: 0.669539 class. loss: 0.234790  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.311111 (theory) =====
# Theory predicted loss for Mixed data model: 0.650506 class. loss: 0.239010  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.355556 (theory) =====
# Theory predicted loss for Mixed data model: 0.633747 class. loss: 0.237660  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.4 (theory) =====
# Theory predicted loss for Mixed data model: 0.616199 class. loss: 0.238590  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.444444 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.600332  std=0.018876   class. loss: 0.239800
#
# ===== delta = 0.444444 (theory) =====
# Theory predicted loss for Mixed data model: 0.599326 class. loss: 0.240450  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.488889 (theory) =====
# Theory predicted loss for Mixed data model: 0.582330 class. loss: 0.240340  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.533333 (theory) =====
# Theory predicted loss for Mixed data model: 0.564016 class. loss: 0.242120  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.577778 (theory) =====
# Theory predicted loss for Mixed data model: 0.544503 class. loss: 0.243000  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.622222 (theory) =====
# Theory predicted loss for Mixed data model: 0.525685 class. loss: 0.244940  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.666667 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.510770  std=0.020358   class. loss: 0.247935
#
# ===== delta = 0.666667 (theory) =====
# Theory predicted loss for Mixed data model: 0.506815 class. loss: 0.249020  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.711111 (theory) =====
# Theory predicted loss for Mixed data model: 0.489998 class. loss: 0.249100  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.755556 (theory) =====
# Theory predicted loss for Mixed data model: 0.474627 class. loss: 0.248380  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.8 (theory) =====
# Theory predicted loss for Mixed data model: 0.456592 class. loss: 0.250020  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.844444 (theory) =====
# Theory predicted loss for Mixed data model: 0.440819 class. loss: 0.248960  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.888889 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.425101  std=0.017874   class. loss: 0.247416
#
# ===== delta = 0.888889 (theory) =====
# Theory predicted loss for Mixed data model: 0.424764 class. loss: 0.250510  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.933333 (theory) =====
# Theory predicted loss for Mixed data model: 0.409247 class. loss: 0.249560  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 0.977778 (theory) =====
# Theory predicted loss for Mixed data model: 0.391742 class. loss: 0.250680  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.02222 (theory) =====
# Theory predicted loss for Mixed data model: 0.377423 class. loss: 0.250650  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.06667 (theory) =====
# Theory predicted loss for Mixed data model: 0.364426 class. loss: 0.256380  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.11111 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.347081  std=0.017270   class. loss: 0.253551
#
# ===== delta = 1.11111 (theory) =====
# Theory predicted loss for Mixed data model: 0.350972 class. loss: 0.251700  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.15556 (theory) =====
# Theory predicted loss for Mixed data model: 0.334647 class. loss: 0.255090  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.2 (theory) =====
# Theory predicted loss for Mixed data model: 0.320442 class. loss: 0.254540  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.24444 (theory) =====
# Theory predicted loss for Mixed data model: 0.307107 class. loss: 0.258170  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.28889 (theory) =====
# Theory predicted loss for Mixed data model: 0.292926 class. loss: 0.257240  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.33333 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.280963  std=0.013082   class. loss: 0.259909
#
# ===== delta = 1.33333 (theory) =====
# Theory predicted loss for Mixed data model: 0.281048 class. loss: 0.259710  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.37778 (theory) =====
# Theory predicted loss for Mixed data model: 0.268778 class. loss: 0.260000  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.42222 (theory) =====
# Theory predicted loss for Mixed data model: 0.256642 class. loss: 0.259790  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.46667 (theory) =====
# Theory predicted loss for Mixed data model: 0.243894 class. loss: 0.255320  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.51111 (theory) =====
# Theory predicted loss for Mixed data model: 0.232850 class. loss: 0.257070  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.55556 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.223053  std=0.013441   class. loss: 0.265711
#
# ===== delta = 1.55556 (theory) =====
# Theory predicted loss for Mixed data model: 0.222306 class. loss: 0.262020  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.6 (theory) =====
# Theory predicted loss for Mixed data model: 0.212432 class. loss: 0.260780  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.64444 (theory) =====
# Theory predicted loss for Mixed data model: 0.201830 class. loss: 0.261800  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.68889 (theory) =====
# Theory predicted loss for Mixed data model: 0.192404 class. loss: 0.263930  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.73333 (theory) =====
# Theory predicted loss for Mixed data model: 0.182648 class. loss: 0.263310  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.77778 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.173996  std=0.012216   class. loss: 0.261774
#
# ===== delta = 1.77778 (theory) =====
# Theory predicted loss for Mixed data model: 0.174125 class. loss: 0.263460  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.82222 (theory) =====
# Theory predicted loss for Mixed data model: 0.165880 class. loss: 0.264490  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.86667 (theory) =====
# Theory predicted loss for Mixed data model: 0.156958 class. loss: 0.268450  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.91111 (theory) =====
# Theory predicted loss for Mixed data model: 0.148477 class. loss: 0.267530  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 1.95556 (theory) =====
# Theory predicted loss for Mixed data model: 0.140016 class. loss: 0.270490  (converged=False, iters=1000, damping_final=0.003)
#
# ===== delta = 2 (empirical gen reg) =====
# Empirical loss for Mixed data: mean=0.136003  std=0.008894   class. loss: 0.275516
#
# ===== delta = 2 (theory) =====
# Theory predicted loss for Mixed data model: 0.133466 class. loss: 0.269880  (converged=False, iters=1000, damping_final=0.003)

# %%
num_trials_th = 100000
scores_emp = dict()
scores_th = dict()
rngz = np.random.default_rng()
rngtst = np.random.default_rng()
z_samples = rngz.standard_normal(size=num_trials_th) 
for c_label in range(K):
    for idx in [0,nb_points_th-1]:
        for model_name in ['Mixed data']:
            theta_star = models[model_name].class_params()['w_values']
            sc_emp=[]
            for i in range(num_trials):
                Xte, ute = models[model_name].sample_class(c_label, n_test, rng=rngtst)
                # eps, yte = self._split_u(ute)
                sc_emp += [Xte[j]@thetas_rcrd[(model_name, idx)][i] for j in range(n_test)]
                # sc_emp += [Xte[j]@(thetas_rcrd[(model_name, idx)][i]-theta_star[c_label]) for j in range(n_test)]
            scores_emp[(model_name, c_label, idx)] = np.array(sc_emp)
            Xtst, utst = models[model_name].sample_class(c_label,num_trials_th, rng=rngtst)
            # epstst, ytst = self._split_u(utst)
            # idx_th = ratio_th_emp*idx
            scores_th[(model_name, c_label, idx)] = Xtst@vars[model_name]["mu"][idx] + vars[model_name]["alpha"][idx][c_label]*z_samples
            # scores_th[(model_name, c_label, idx)] = Xtst@(vars[model_name]["mu"][idx_th]-theta_star[c_label]) + vars[model_name]["alpha"][idx_th][c_label]*z_samples

# %%
# --- Reset font settings for a modern, clean look ---
from matplotlib import patheffects
from sklearn.neighbors import KernelDensity
from scipy.stats import norm
from matplotlib.gridspec import GridSpec
import logging
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# --- PLOT SETTINGS ---
plt.rcParams['text.usetex'] = False
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1.5
plt.rcParams['ytick.major.width'] = 1.5


colors = {
    'Mixed data':{
    'Real data':{
        0: '#2CA02C',
        1: '#97B33C',
    },
    'Generated data':
    {
        0: '#1F77B4',
        1: '#9467BD',
    },
    }    
}

fig = plt.figure(figsize=(28, 15))

gs = GridSpec(
    nrows=2,
    ncols=3,
    # height_ratios=[1, 1],  # adjust if needed
    width_ratios=[1, 2,1],  # adjust if needed
    hspace=0.8,
    wspace=0.3
)

model_names = ['Mixed data']
axes_histo = {0 :{0: {'Mixed data' : fig.add_subplot(gs[0, 0])},
                  1: {'Mixed data' : fig.add_subplot(gs[1, 0])}},
              1: {0: {'Mixed data' : fig.add_subplot(gs[0, 2])},
                  1: {'Mixed data' : fig.add_subplot(gs[1, 2])}}}
ax_mid = fig.add_subplot(gs[0, 1])
ax_mid_low = fig.add_subplot(gs[1,1])

# Bottom: spans both columns
# --- LEFT PANEL: Histograms + PDFs ---
alpha = {'Mixed data':0.6,'Real data':0.2, 'Generated data':0.2}
# idx_delta = 0
for i_ax, idx_th in enumerate([0,nb_points_th-1]):
    for cl, rl_gen in enumerate(['Real data','Generated data']):
        for model_name in model_names:
            model = models[model_name]
            for ss_cl in range(model.K_base):
                c_label = cl*model.K_base+ ss_cl
                axes_histo[i_ax][cl][model_name].hist(
                    scores_emp[(model_name, c_label, idx_th)],
                    bins=30,
                    density=True,
                    alpha=alpha[model_name],
                    color=colors[model_name][rl_gen][ss_cl],
                    edgecolor='white',
                    linewidth=2,
                    label=f'{model_name} score' 
                )
                scth = scores_th[(model_name, c_label, idx_th)]
                x = np.linspace(np.mean(scth) - 4 * np.std(scth), np.mean(scth) + 4 * np.std(scth), 500)
                bandwidth = np.std(scth)/10
                kde = KernelDensity(kernel='gaussian', bandwidth=bandwidth).fit(scth.reshape(-1, 1))
                log_dens = kde.score_samples(x.reshape(-1, 1))
                axes_histo[i_ax][cl][model_name].plot(
                    x,
                    np.exp(log_dens),
                    color=colors[model_name][rl_gen][ss_cl],
                    linewidth=3.5,
                    linestyle='-.',
                    label=f'Theoretical density',
                    path_effects=[patheffects.withStroke(linewidth=6, foreground='white', alpha=0.8)]
                )
                print(f"Plotted KDE for {model_name}, class {c_label}, delta={deltas_th[idx_th]:.2f}:\n mean: {np.mean(scth)},  std: {np.std(scth)}")
                # axes_histo[i_ax][cl][model_name].plot(
                #     x,
                #     norm.pdf(x, np.mean(scth),  np.std(scth)),
                #     linestyle='--',
                #     color=colors[model_name]['score_univ'],
                #     linewidth=2.5,
                #     label=f'Gaussian fit',
                #     alpha=0.8
                # )

            axes_histo[i_ax][cl][model_name].set_title(r"Score histograms $x^\top\mu$ of {rl_gen} for $\delta =$ {delta}".format(rl_gen= rl_gen, delta=deltas_th[idx_th]), pad=20, fontweight='bold')
            axes_histo[i_ax][cl][model_name].set_xlabel("Decision Score", labelpad=10)
            axes_histo[i_ax][cl][model_name].set_ylabel("Density", labelpad=10)
            axes_histo[i_ax][cl][model_name].legend(loc='lower right', frameon=True, framealpha=1, edgecolor='white')
    # axes_histo[eta].grid(True, linestyle='-', color=colors['grid'], alpha=0.3)


# --- MIDDLE UPPER PANEL: Classification Error ---
for model_name in model_names:

    ax_mid.plot(
        deltas_th,
        vars[model_name]['error_th'],
        color='b',
        linewidth=3.5,
        label=f'Theoretical Error {model_name}',
        path_effects=[patheffects.withStroke(linewidth=5, foreground='white', alpha=0.5)]
    )
    ax_mid.plot(
        deltas,
        vars[model_name]['error_emp_means'],
        color='b',
        linestyle ='none',
        linewidth=3.5,
        label=f'Empirical Error {model_name}',
        marker='o',
        markersize=9,
        markerfacecolor='white',
        markeredgewidth=2,
        markeredgecolor='b'
        # colors['empirical']
    )
    ax_mid_low.plot(
        deltas_th,
        vars[model_name]['error_classif_th'],
        color='b',
        linewidth=3.5,
        label=f'Theoretical Error {model_name}',
        path_effects=[patheffects.withStroke(linewidth=5, foreground='white', alpha=0.5)]
    )
    ax_mid_low.plot(
        deltas,
        vars[model_name]['error_classif_emp'],
        color='b',
        linestyle ='none',
        linewidth=3.5,
        label=f'Empirical Error {model_name}',
        marker='o',
        markersize=9,
        markerfacecolor='white',
        markeredgewidth=2,
        markeredgecolor='b'
        # colors['empirical']
    )


# --- Styling ---
ax_mid.set_title(r"Generalizing loss vs pruning threshold $\delta$", pad=20, fontweight='bold')
# ax_mid.set_xlabel("Regularization Parameter ($\lambda$)", labelpad=10)
ax_mid.set_ylabel("Generalizing loss", labelpad=10)
ax_mid.legend(loc='upper left', frameon=True, framealpha=0.9, edgecolor='white', title='Error Curves')
# ax_mid.grid(True, linestyle='-', color=colors['grid'], alpha=0.3)
ax_mid_low.set_title(r"Classification Error vs pruning threshold $\delta$", pad=20, fontweight='bold')
# ax_mid_low.set_xlabel("Regularization Parameter ($\lambda$)", labelpad=10)
ax_mid_low.set_ylabel("Classification Error", labelpad=10)
ax_mid_low.legend(loc='upper left', frameon=True, framealpha=0.9, edgecolor='white', title='Error Curves')
# ax_mid.grid(True, linestyle='-', color=colors['grid'], alpha=0.3)

# --- Save in high quality ---
plt.tight_layout()
# fig.savefig("ICML_teaser_figure.pdf", bbox_inches='tight', dpi=1200, transparent=True)
# fig.savefig("ICML_teaser_figure.png", bbox_inches='tight', dpi=1200, transparent=True)
plt.show()
# Out:
# Plotted KDE for Mixed data, class 0, delta=0.00:
#  mean: 0.3664178603743363,  std: 0.37396545048875635
# Plotted KDE for Mixed data, class 1, delta=0.00:
#  mean: -0.3686839697759669,  std: 0.3720350720078197
# Plotted KDE for Mixed data, class 2, delta=0.00:
#  mean: 0.3691807697537523,  std: 0.37353337223185007
# Plotted KDE for Mixed data, class 3, delta=0.00:
#  mean: -0.3672435131982472,  std: 0.3735174494078986
# Plotted KDE for Mixed data, class 0, delta=2.00:
#  mean: 0.1252564310575885,  std: 0.1352385326019539
# Plotted KDE for Mixed data, class 1, delta=2.00:
#  mean: -0.12570133487118476,  std: 0.1350929818681985
# Plotted KDE for Mixed data, class 2, delta=2.00:
#  mean: 0.1260791951227238,  std: 0.13543244909865884
# Plotted KDE for Mixed data, class 3, delta=2.00:
#  mean: -0.12529460278158455,  std: 0.135481383561667
# /tmp/ipykernel_3549/1731292178.py:164: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
